# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam
from time import time

# %%
def ChangeDateFormat(date):
    month = date // 100
    day = date % 100
    date = '2020-' + str(month) + '-' + str(day)
    return pd.Timestamp(date)

# %%
# code for importing the original data.
info = pd.read_csv('/work/ma384/Share/Team_Repeat_Buyer/user_info_format1.csv')
log = pd.read_csv('/work/ma384/Share/Team_Repeat_Buyer/user_log_format1.csv')
df_train = pd.read_csv('/work/ma384/Share/Team_Repeat_Buyer/train_format1.csv')

# %%
info['age_range'] = info['age_range'].fillna(0)
info['gender'] = info['gender'].fillna(2)
info['age_range'] = info['age_range'].astype('category')
info['gender'] = info['gender'].astype('category')
info['age_range'] = info['age_range'].replace(8, 7)

# %%
log['time_stamp'] = log['time_stamp'].apply(lambda x: ChangeDateFormat(x))

# %% [markdown]
# ### Seller infor

# %%
seller_item_count = log[['seller_id','item_id']]
seller_item_count = seller_item_count.drop_duplicates()
seller_item_count['seller_item_count'] = 1
seller_item_count = seller_item_count.groupby(['seller_id']).agg('sum')
seller_item_count = seller_item_count.drop(columns=['item_id'])
seller_item_count.head()
# Out:
#            seller_item_count
# seller_id
# 1                       2977
# 2                        154
# 3                        171
# 4                        155
# 5                        660

# %%
seller_brand_count = log[['seller_id','brand_id']]
seller_brand_count = seller_brand_count.drop_duplicates()
seller_brand_count = seller_brand_count.groupby(['seller_id']).agg(len)
seller_brand_count.rename(columns = {"brand_id": "brand_count"},inplace=True) 
seller_brand_count.head()
# Out:
#            brand_count
# seller_id
# 1                  3.0
# 2                  2.0
# 3                  2.0
# 4                  3.0
# 5                  2.0

# %%
item_info = log['item_id'].value_counts()
cat_info = log['cat_id'].value_counts()
brand_info = log['brand_id'].value_counts()
seller_info = log['seller_id'].value_counts()
print(item_info.head(), item_info.size)
print(cat_info.head(),cat_info.size)
print(brand_info.head(),brand_info.size)
print(seller_info.head(),seller_info.size)
# Out:
# 67897     345905
# 783997    178005
# 636863     82480
# 631714     42771
# 61518      34801
# Name: item_id, dtype: int64 1090390
# 662     4339025
# 737     1749753
# 1505    1724239
# 389     1621736
# 656     1538969
# Name: cat_id, dtype: int64 1658
# 3738.0    763345
# 1360.0    737545
# 1446.0    729555
# 1214.0    541075
# 5376.0    528003
# Name: brand_id, dtype: int64 8443
# 3760    743217
# 3828    730455
# 184     613811
# 1102    541374
# 4173    528755
# Name: seller_id, dtype: int64 4995

# %% [markdown]
# ### User action

# %%
actions = log.action_type
actions = pd.get_dummies(actions,prefix='action_count')
user_action = pd.concat([log.user_id,actions],axis=1)
user_action = user_action.groupby('user_id').agg('sum')
user_action.head()
# Out:
#          action_count_0  action_count_1  action_count_2  action_count_3
# user_id
# 1                  27.0             0.0             6.0             0.0
# 2                  47.0             0.0            14.0             2.0
# 3                  63.0             0.0             4.0             1.0
# 4                  49.0             0.0             1.0             0.0
# 5                 150.0             0.0            13.0            10.0

# %% [markdown]
# ### Merge

# %%
df_Train = pd.read_csv('/work/ma384/Share/Team_Repeat_Buyer/train_format1.csv')

# %%
seller = seller_item_count.merge(seller_brand_count,on='seller_id')
df_train = df_Train.merge(seller,left_on='merchant_id',right_on='seller_id')
df_train = df_train.merge(user_action,on='user_id')
log_dummy = pd.get_dummies(log['action_type'],prefix='action')
log_dummy = pd.concat([log.user_id,log.seller_id,actions],axis=1)
log_dummy.columns = ['user_id', 'merchant_id', 'action_0', 'action_1',
       'action_2', 'action_3']
log_dummy = log_dummy.groupby(['user_id','merchant_id']).agg('sum')
df_train = df_train.merge(log_dummy,on=['merchant_id','user_id'])

# %%
df_train.head(3)
# Out:
#    user_id  merchant_id  label  seller_item_count  brand_count  \
# 0    34176         3906      0                308          2.0
# 1    34176          121      0               1179          2.0
# 2    34176         4356      1                 67          2.0
#
#    action_count_0  action_count_1  action_count_2  action_count_3  action_0  \
# 0           410.0             0.0            34.0             7.0      36.0
# 1           410.0             0.0            34.0             7.0      13.0
# 2           410.0             0.0            34.0             7.0      12.0
#
#    action_1  action_2  action_3
# 0       0.0       1.0       2.0
# 1       0.0       1.0       0.0
# 2       0.0       6.0       0.0

# %%
train, test = train_test_split(df_train,test_size=0.2,random_state=0,shuffle=True,stratify=df_train.label)

# %%
targets_train = train.label.values
targets_test = test.label.values
attributes_train = train.drop(['merchant_id','user_id','label'],axis=1).values
attributes_test = test.drop(['merchant_id','user_id','label'],axis=1).values

# %%
attributes_train = (attributes_train - attributes_train.mean(axis=0))/attributes_train.std(axis=0)
attributes_test = (attributes_test - attributes_test.mean(axis=0))/attributes_test.std(axis=0)

# %% [markdown]
# ### NN (Stacked LR with ReLU)

# %%
stacked_lr_with_relu = Sequential()
stacked_lr_with_relu.add(Dense(10, input_shape=(10,), activation='relu'))
stacked_lr_with_relu.add(Dense(2, input_shape=(10,), activation=None))

stacked_lr_with_relu.compile(loss='sparse_categorical_crossentropy',
                            optimizer=Adam(learning_rate=1e-5),
                            metrics=['accuracy'])

stacked_lr_with_relu.summary()
# Out:
# Model: "sequential_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_26 (Dense)             (None, 10)                110
# _________________________________________________________________
# dense_27 (Dense)             (None, 2)                 22
# =================================================================
# Total params: 132
# Trainable params: 132
# Non-trainable params: 0
# _________________________________________________________________

# %%
save_best = ModelCheckpoint('nn1.h5', save_best_only=True, verbose=2)
early_stopping = EarlyStopping(monitor="val_loss", patience=5)

# %%
time_start = time()
hist = stacked_lr_with_relu.fit(attributes_train, targets_train, epochs=50, 
                                callbacks=[save_best, early_stopping], 
                                validation_split=0.2, verbose=1)
time_stop = time()
time_elapsed = time_stop - time_start
print(time_elapsed / 60, '(min)')
# Out:
# Train on 166952 samples, validate on 41739 samples
# Epoch 1/50
# 166720/166952 [============================>.] - ETA: 0s - loss: 2.7188 - accuracy: 0.7355
# Epoch 00001: val_loss improved from inf to 2.58197, saving model to nn1.h5
# 166952/166952 [==============================] - 24s 142us/sample - loss: 2.7184 - accuracy: 0.7356 - val_loss: 2.5820 - val_accuracy: 0.7446
# Epoch 2/50
# 166912/166952 [============================>.] - ETA: 0s - loss: 2.4718 - accuracy: 0.7481
# Epoch 00002: val_loss improved from 2.58197 to 2.35933, saving model to nn1.h5
# 166952/166952 [==============================] - 25s 149us/sample - loss: 2.4716 - accuracy: 0.7481 - val_loss: 2.3593 - val_accuracy: 0.7546
# Epoch 3/50
# 166848/166952 [============================>.] - ETA: 0s - loss: 2.2769 - accuracy: 0.7571
# Epoch 00003: val_loss improved from 2.35933 to 2.16493, saving model to nn1.h5
# 166952/166952 [==============================] - 23s 140us/sample - loss: 2.2771 - accuracy: 0.7571 - val_loss: 2.1649 - val_accuracy: 0.7622
# Epoch 4/50
# 166528/166952 [============================>.] - ETA: 0s - loss: 2.0860 - accuracy: 0.7660
# Epoch 00004: val_loss improved from 2.16493 to 1.95553, saving model to nn1.h5
# 166952/166952 [==============================] - 23s 141us/sample - loss: 2.0875 - accuracy: 0.7658 - val_loss: 1.9555 - val_accuracy: 0.7721
# Epoch 5/50
# 166912/166952 [============================>.] - ETA: 0s - loss: 1.9084 - accuracy: 0.7750
# Epoch 00005: val_loss improved from 1.95553 to 1.81092, saving model to nn1.h5
# 166952/166952 [==============================] - 24s 142us/sample - loss: 1.9082 - accuracy: 0.7750 - val_loss: 1.8109 - val_accuracy: 0.7800
# Epoch 6/50
# 166816/166952 [============================>.] - ETA: 0s - loss: 1.7868 - accuracy: 0.7829
# Epoch 00006: val_loss improved from 1.81092 to 1.70039, saving model to nn1.h5
# 166952/166952 [==============================] - 23s 139us/sample - loss: 1.7869 - accuracy: 0.7829 - val_loss: 1.7004 - val_accuracy: 0.7866
# Epoch 7/50
# 166592/166952 [============================>.] - ETA: 0s - loss: 1.6534 - accuracy: 0.7921
# Epoch 00007: val_loss improved from 1.70039 to 1.55168, saving model to nn1.h5
# 166952/166952 [==============================] - 22s 135us/sample - loss: 1.6532 - accuracy: 0.7922 - val_loss: 1.5517 - val_accuracy: 0.7986
# Epoch 8/50
# 166912/166952 [============================>.] - ETA: 0s - loss: 1.5082 - accuracy: 0.8039
# Epoch 00008: val_loss improved from 1.55168 to 1.43775, saving model to nn1.h5
# 166952/166952 [==============================] - 23s 139us/sample - loss: 1.5082 - accuracy: 0.8039 - val_loss: 1.4378 - val_accuracy: 0.8096
# Epoch 9/50
# 166528/166952 [============================>.] - ETA: 0s - loss: 1.4230 - accuracy: 0.8124
# Epoch 00009: val_loss improved from 1.43775 to 1.36528, saving model to nn1.h5
# 166952/166952 [==============================] - 22s 133us/sample - loss: 1.4237 - accuracy: 0.8124 - val_loss: 1.3653 - val_accuracy: 0.8176
# Epoch 10/50
# 166784/166952 [============================>.] - ETA: 0s - loss: 1.3471 - accuracy: 0.8208
# Epoch 00010: val_loss improved from 1.36528 to 1.30310, saving model to nn1.h5
# 166952/166952 [==============================] - 23s 138us/sample - loss: 1.3465 - accuracy: 0.8209 - val_loss: 1.3031 - val_accuracy: 0.8246
# Epoch 11/50
# 166912/166952 [============================>.] - ETA: 0s - loss: 1.2931 - accuracy: 0.8272
# Epoch 00011: val_loss improved from 1.30310 to 1.23740, saving model to nn1.h5
# 166952/166952 [==============================] - 24s 145us/sample - loss: 1.2933 - accuracy: 0.8272 - val_loss: 1.2374 - val_accuracy: 0.8326
# Epoch 12/50
# 166720/166952 [============================>.] - ETA: 0s - loss: 1.2197 - accuracy: 0.8363
# Epoch 00012: val_loss improved from 1.23740 to 1.16521, saving model to nn1.h5
# 166952/166952 [==============================] - 24s 145us/sample - loss: 1.2201 - accuracy: 0.8363 - val_loss: 1.1652 - val_accuracy: 0.8413
# Epoch 13/50
# 166592/166952 [============================>.] - ETA: 0s - loss: 1.1661 - accuracy: 0.8425
# Epoch 00013: val_loss improved from 1.16521 to 1.11999, saving model to nn1.h5
# 166952/166952 [==============================] - 23s 138us/sample - loss: 1.1662 - accuracy: 0.8425 - val_loss: 1.1200 - val_accuracy: 0.8468
# Epoch 14/50
# 166528/166952 [============================>.] - ETA: 0s - loss: 1.1147 - accuracy: 0.8467
# Epoch 00014: val_loss improved from 1.11999 to 1.05214, saving model to nn1.h5
# 166952/166952 [==============================] - 23s 139us/sample - loss: 1.1139 - accuracy: 0.8467 - val_loss: 1.0521 - val_accuracy: 0.8514
# Epoch 15/50
# 166656/166952 [============================>.] - ETA: 0s - loss: 1.0294 - accuracy: 0.8521
# Epoch 00015: val_loss improved from 1.05214 to 0.98523, saving model to nn1.h5
# 166952/166952 [==============================] - 24s 141us/sample - loss: 1.0288 - accuracy: 0.8522 - val_loss: 0.9852 - val_accuracy: 0.8569
# Epoch 16/50
# 166944/166952 [============================>.] - ETA: 0s - loss: 0.9780 - accuracy: 0.8557
# Epoch 00016: val_loss improved from 0.98523 to 0.94418, saving model to nn1.h5
# 166952/166952 [==============================] - 23s 138us/sample - loss: 0.9780 - accuracy: 0.8557 - val_loss: 0.9442 - val_accuracy: 0.8600
# Epoch 17/50
# 166560/166952 [============================>.] - ETA: 0s - loss: 0.9298 - accuracy: 0.8580
# Epoch 00017: val_loss improved from 0.94418 to 0.90745, saving model to nn1.h5
# 166952/166952 [==============================] - 23s 140us/sample - loss: 0.9300 - accuracy: 0.8580 - val_loss: 0.9075 - val_accuracy: 0.8617
# Epoch 18/50
# 166624/166952 [============================>.] - ETA: 0s - loss: 0.9036 - accuracy: 0.8599
# Epoch 00018: val_loss improved from 0.90745 to 0.88419, saving model to nn1.h5
# 166952/166952 [==============================] - 24s 141us/sample - loss: 0.9036 - accuracy: 0.8599 - val_loss: 0.8842 - val_accuracy: 0.8632
# Epoch 19/50
# 166752/166952 [============================>.] - ETA: 0s - loss: 0.8779 - accuracy: 0.8615
# Epoch 00019: val_loss improved from 0.88419 to 0.85998, saving model to nn1.h5
# 166952/166952 [==============================] - 23s 136us/sample - loss: 0.8781 - accuracy: 0.8615 - val_loss: 0.8600 - val_accuracy: 0.8650
# Epoch 20/50
# 166880/166952 [============================>.] - ETA: 0s - loss: 0.8485 - accuracy: 0.8636
# Epoch 00020: val_loss improved from 0.85998 to 0.83626, saving model to nn1.h5
# 166952/166952 [==============================] - 23s 137us/sample - loss: 0.8485 - accuracy: 0.8636 - val_loss: 0.8363 - val_accuracy: 0.8664
# Epoch 21/50
# 166624/166952 [============================>.] - ETA: 0s - loss: 0.8333 - accuracy: 0.8635
# Epoch 00021: val_loss improved from 0.83626 to 0.82642, saving model to nn1.h5
# 166952/166952 [==============================] - 23s 136us/sample - loss: 0.8339 - accuracy: 0.8635 - val_loss: 0.8264 - val_accuracy: 0.8652
# Epoch 22/50
# 166528/166952 [============================>.] - ETA: 0s - loss: 0.8239 - accuracy: 0.8621
# Epoch 00022: val_loss improved from 0.82642 to 0.81769, saving model to nn1.h5
# 166952/166952 [==============================] - 23s 140us/sample - loss: 0.8235 - accuracy: 0.8621 - val_loss: 0.8177 - val_accuracy: 0.8635
# Epoch 23/50
# 166656/166952 [============================>.] - ETA: 0s - loss: 0.8138 - accuracy: 0.8610
# Epoch 00023: val_loss improved from 0.81769 to 0.80752, saving model to nn1.h5
# 166952/166952 [==============================] - 24s 146us/sample - loss: 0.8143 - accuracy: 0.8610 - val_loss: 0.8075 - val_accuracy: 0.8640
# Epoch 24/50
# 166912/166952 [============================>.] - ETA: 0s - loss: 0.8052 - accuracy: 0.8612
# Epoch 00024: val_loss improved from 0.80752 to 0.79946, saving model to nn1.h5
# 166952/166952 [==============================] - 24s 141us/sample - loss: 0.8052 - accuracy: 0.8612 - val_loss: 0.7995 - val_accuracy: 0.8637
# Epoch 25/50
# 166688/166952 [============================>.] - ETA: 0s - loss: 0.7946 - accuracy: 0.8611
# Epoch 00025: val_loss improved from 0.79946 to 0.79067, saving model to nn1.h5
# 166952/166952 [==============================] - 23s 139us/sample - loss: 0.7947 - accuracy: 0.8611 - val_loss: 0.7907 - val_accuracy: 0.8637
# Epoch 26/50
# 166944/166952 [============================>.] - ETA: 0s - loss: 0.7870 - accuracy: 0.8596
# Epoch 00026: val_loss improved from 0.79067 to 0.78433, saving model to nn1.h5
# 166952/166952 [==============================] - 24s 145us/sample - loss: 0.7871 - accuracy: 0.8596 - val_loss: 0.7843 - val_accuracy: 0.8610
# Epoch 27/50
# 166816/166952 [============================>.] - ETA: 0s - loss: 0.7818 - accuracy: 0.8575
# Epoch 00027: val_loss improved from 0.78433 to 0.77920, saving model to nn1.h5
# 166952/166952 [==============================] - 23s 138us/sample - loss: 0.7818 - accuracy: 0.8575 - val_loss: 0.7792 - val_accuracy: 0.8608
# Epoch 28/50
# 166784/166952 [============================>.] - ETA: 0s - loss: 0.7780 - accuracy: 0.8580
# Epoch 00028: val_loss improved from 0.77920 to 0.77790, saving model to nn1.h5
# 166952/166952 [==============================] - 23s 138us/sample - loss: 0.7777 - accuracy: 0.8581 - val_loss: 0.7779 - val_accuracy: 0.8606
# Epoch 29/50
# 166912/166952 [============================>.] - ETA: 0s - loss: 0.7746 - accuracy: 0.8572
# Epoch 00029: val_loss improved from 0.77790 to 0.77470, saving model to nn1.h5
# 166952/166952 [==============================] - 24s 147us/sample - loss: 0.7747 - accuracy: 0.8572 - val_loss: 0.7747 - val_accuracy: 0.8596
# Epoch 30/50
# 166496/166952 [============================>.] - ETA: 0s - loss: 0.7700 - accuracy: 0.8553
# Epoch 00030: val_loss improved from 0.77470 to 0.77080, saving model to nn1.h5
# 166952/166952 [==============================] - 24s 143us/sample - loss: 0.7705 - accuracy: 0.8553 - val_loss: 0.7708 - val_accuracy: 0.8565
# Epoch 31/50
# 166912/166952 [============================>.] - ETA: 0s - loss: 0.7620 - accuracy: 0.8520
# Epoch 00031: val_loss improved from 0.77080 to 0.76400, saving model to nn1.h5
# 166952/166952 [==============================] - 24s 146us/sample - loss: 0.7619 - accuracy: 0.8520 - val_loss: 0.7640 - val_accuracy: 0.8529
# Epoch 32/50
# 166784/166952 [============================>.] - ETA: 0s - loss: 0.7559 - accuracy: 0.8481
# Epoch 00032: val_loss improved from 0.76400 to 0.75839, saving model to nn1.h5
# 166952/166952 [==============================] - 23s 138us/sample - loss: 0.7556 - accuracy: 0.8481 - val_loss: 0.7584 - val_accuracy: 0.8475
# Epoch 33/50
# 166464/166952 [============================>.] - ETA: 0s - loss: 0.7501 - accuracy: 0.8431
# Epoch 00033: val_loss improved from 0.75839 to 0.75509, saving model to nn1.h5
# 166952/166952 [==============================] - 24s 144us/sample - loss: 0.7500 - accuracy: 0.8431 - val_loss: 0.7551 - val_accuracy: 0.8437
# Epoch 34/50
# 166880/166952 [============================>.] - ETA: 0s - loss: 0.7456 - accuracy: 0.8405
# Epoch 00034: val_loss improved from 0.75509 to 0.75342, saving model to nn1.h5
# 166952/166952 [==============================] - 23s 138us/sample - loss: 0.7456 - accuracy: 0.8404 - val_loss: 0.7534 - val_accuracy: 0.8423
# Epoch 35/50
# 166880/166952 [============================>.] - ETA: 0s - loss: 0.7431 - accuracy: 0.8402
# Epoch 00035: val_loss improved from 0.75342 to 0.74923, saving model to nn1.h5
# 166952/166952 [==============================] - 23s 135us/sample - loss: 0.7431 - accuracy: 0.8402 - val_loss: 0.7492 - val_accuracy: 0.8416
# Epoch 36/50
# 166592/166952 [============================>.] - ETA: 0s - loss: 0.7399 - accuracy: 0.8384
# Epoch 00036: val_loss improved from 0.74923 to 0.74716, saving model to nn1.h5
# 166952/166952 [==============================] - 23s 140us/sample - loss: 0.7400 - accuracy: 0.8384 - val_loss: 0.7472 - val_accuracy: 0.8391
# Epoch 37/50
# 166848/166952 [============================>.] - ETA: 0s - loss: 0.7354 - accuracy: 0.8349
# Epoch 00037: val_loss improved from 0.74716 to 0.74198, saving model to nn1.h5
# 166952/166952 [==============================] - 23s 139us/sample - loss: 0.7356 - accuracy: 0.8349 - val_loss: 0.7420 - val_accuracy: 0.8346
# Epoch 38/50
# 166528/166952 [============================>.] - ETA: 0s - loss: 0.7275 - accuracy: 0.8288
# Epoch 00038: val_loss improved from 0.74198 to 0.73581, saving model to nn1.h5
# 166952/166952 [==============================] - 23s 137us/sample - loss: 0.7272 - accuracy: 0.8289 - val_loss: 0.7358 - val_accuracy: 0.8276
# Epoch 39/50
# 166784/166952 [============================>.] - ETA: 0s - loss: 0.7204 - accuracy: 0.8234
# Epoch 00039: val_loss improved from 0.73581 to 0.73350, saving model to nn1.h5
# 166952/166952 [==============================] - 24s 143us/sample - loss: 0.7202 - accuracy: 0.8234 - val_loss: 0.7335 - val_accuracy: 0.8239
# Epoch 40/50
# 166496/166952 [============================>.] - ETA: 0s - loss: 0.7167 - accuracy: 0.8203
# Epoch 00040: val_loss improved from 0.73350 to 0.73059, saving model to nn1.h5
# 166952/166952 [==============================] - 23s 140us/sample - loss: 0.7168 - accuracy: 0.8204 - val_loss: 0.7306 - val_accuracy: 0.8206
# Epoch 41/50
# 166912/166952 [============================>.] - ETA: 0s - loss: 0.7164 - accuracy: 0.8174
# Epoch 00041: val_loss did not improve from 0.73059
# 166952/166952 [==============================] - 22s 134us/sample - loss: 0.7163 - accuracy: 0.8175 - val_loss: 0.7309 - val_accuracy: 0.8173
# Epoch 42/50
# 166752/166952 [============================>.] - ETA: 0s - loss: 0.7166 - accuracy: 0.8136
# Epoch 00042: val_loss did not improve from 0.73059
# 166952/166952 [==============================] - 24s 141us/sample - loss: 0.7167 - accuracy: 0.8136 - val_loss: 0.7316 - val_accuracy: 0.8139
# Epoch 43/50
# 166688/166952 [============================>.] - ETA: 0s - loss: 0.7147 - accuracy: 0.8121
# Epoch 00043: val_loss improved from 0.73059 to 0.72980, saving model to nn1.h5
# 166952/166952 [==============================] - 24s 143us/sample - loss: 0.7148 - accuracy: 0.8121 - val_loss: 0.7298 - val_accuracy: 0.8141
# Epoch 44/50
# 166688/166952 [============================>.] - ETA: 0s - loss: 0.7142 - accuracy: 0.8125
# Epoch 00044: val_loss improved from 0.72980 to 0.72911, saving model to nn1.h5
# 166952/166952 [==============================] - 22s 135us/sample - loss: 0.7138 - accuracy: 0.8125 - val_loss: 0.7291 - val_accuracy: 0.8141
# Epoch 45/50
# 166656/166952 [============================>.] - ETA: 0s - loss: 0.7129 - accuracy: 0.8125
# Epoch 00045: val_loss did not improve from 0.72911
# 166952/166952 [==============================] - 23s 136us/sample - loss: 0.7128 - accuracy: 0.8125 - val_loss: 0.7304 - val_accuracy: 0.8138
# Epoch 46/50
# 166752/166952 [============================>.] - ETA: 0s - loss: 0.7138 - accuracy: 0.8115
# Epoch 00046: val_loss did not improve from 0.72911
# 166952/166952 [==============================] - 24s 144us/sample - loss: 0.7136 - accuracy: 0.8115 - val_loss: 0.7313 - val_accuracy: 0.8121
# Epoch 47/50
# 166656/166952 [============================>.] - ETA: 0s - loss: 0.7139 - accuracy: 0.8098
# Epoch 00047: val_loss did not improve from 0.72911
# 166952/166952 [==============================] - 23s 140us/sample - loss: 0.7136 - accuracy: 0.8098 - val_loss: 0.7363 - val_accuracy: 0.8110
# Epoch 48/50
# 166752/166952 [============================>.] - ETA: 0s - loss: 0.7150 - accuracy: 0.8077
# Epoch 00048: val_loss did not improve from 0.72911
# 166952/166952 [==============================] - 24s 146us/sample - loss: 0.7149 - accuracy: 0.8076 - val_loss: 0.7402 - val_accuracy: 0.8070
# Epoch 49/50
# 166784/166952 [============================>.] - ETA: 0s - loss: 0.7170 - accuracy: 0.8059
# Epoch 00049: val_loss did not improve from 0.72911
# 166952/166952 [==============================] - 24s 143us/sample - loss: 0.7171 - accuracy: 0.8059 - val_loss: 0.7390 - val_accuracy: 0.8073
# 19.122283061345417 (min)

# %%
targeth_train = np.argmax(stacked_lr_with_relu.predict(attributes_train), axis=1)
targeth_test  = np.argmax(stacked_lr_with_relu.predict(attributes_test), axis=1)

# %%
print("train accuracy", round((targeth_train == targets_train).mean(), 3))
print("test accuracy", round((targeth_test == targets_test).mean(), 3))
# Out:
# train accuracy 0.806
# test accuracy 0.803
